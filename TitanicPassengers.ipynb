# %% [markdown]
# # Titanic Passengers
# By [Solomon Stevens](https://github.com/Stone-Snevets/datafun-05-data-at-rest)    Date: September 22,2023

# %% [markdown]
# ## Follow instructions on page 346 in textbook

# %% [markdown]
# ### Section 1: Load

# %%
# Imports
import pandas as pd

# Read in Titanic Disaster dataset csv file
titanic = pd.read_csv('https://raw.githubusercontent.com/pandas-dev/pandas/main/doc/data/titanic.csv')

# %% [markdown]
# ### Section 2: View

# %%
# Set precision to 2 decimal places
pd.set_option("display.precision", 2)

# %%
# View the head of the file
titanic.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket   Fare Cabin Embarked
# 0      0         A/5 21171   7.25   NaN        S
# 1      0          PC 17599  71.28   C85        C
# 2      0  STON/O2. 3101282   7.92   NaN        S
# 3      0            113803  53.10  C123        S
# 4      0            373450   8.05   NaN        S

# %%
# View the tail of the file
titanic.tail()
# Out:
#      PassengerId  Survived  Pclass                                      Name  \
# 886          887         0       2                     Montvila, Rev. Juozas
# 887          888         1       1              Graham, Miss. Margaret Edith
# 888          889         0       3  Johnston, Miss. Catherine Helen "Carrie"
# 889          890         1       1                     Behr, Mr. Karl Howell
# 890          891         0       3                       Dooley, Mr. Patrick
#
#         Sex   Age  SibSp  Parch      Ticket   Fare Cabin Embarked
# 886    male  27.0      0      0      211536  13.00   NaN        S
# 887  female  19.0      0      0      112053  30.00   B42        S
# 888  female   NaN      1      2  W./C. 6607  23.45   NaN        S
# 889    male  26.0      0      0      111369  30.00  C148        C
# 890    male  32.0      0      0      370376   7.75   NaN        Q

# %% [markdown]
# ### Section 3: Headings

# %%
# Customize column headings
titanic.columns = ['Passenger_ID', 'Survived', 'Passenger_Class', 'Name', 'Gender', 'Age', 'SibSp', 'Parch', 'Ticket_Number', 'Fare', 'Cabin_Number', 'Embarked']

# We can check the new column names using head()
titanic.head()
# Out:
#    Passenger_ID  Survived  Passenger_Class  \
# 0             1         0                3
# 1             2         1                1
# 2             3         1                3
# 3             4         1                1
# 4             5         0                3
#
#                                                 Name  Gender   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch     Ticket_Number   Fare Cabin_Number Embarked
# 0      0         A/5 21171   7.25          NaN        S
# 1      0          PC 17599  71.28          C85        C
# 2      0  STON/O2. 3101282   7.92          NaN        S
# ...

# %% [markdown]
# ### Section 4: Describe

# %%
# Use describe() to calculate basic descriptive statistics for all NUMERIC columns
titanic.describe()
# Out:
#        Passenger_ID  Survived  Passenger_Class     Age   SibSp   Parch    Fare
# count        891.00    891.00           891.00  714.00  891.00  891.00  891.00
# mean         446.00      0.38             2.31   29.70    0.52    0.38   32.20
# std          257.35      0.49             0.84   14.53    1.10    0.81   49.69
# min            1.00      0.00             1.00    0.42    0.00    0.00    0.00
# 25%          223.50      0.00             2.00   20.12    0.00    0.00    7.91
# 50%          446.00      0.00             3.00   28.00    0.00    0.00   14.45
# 75%          668.50      1.00             3.00   38.00    1.00    0.00   31.00
# max          891.00      1.00             3.00   80.00    8.00    6.00  512.33

# %% [markdown]
# ### Section 5: Survivors

# %%
# Follow instructions on page 347 to show descriptive statistics of just the survivors
(titanic.Survived == 'yes').describe()
# Out:
# count       891
# unique        1
# top       False
# freq        891
# Name: Survived, dtype: object

# %% [markdown]
# ### Section 6: Histogram

# %%
# Use DataFrame's hist() function to create a histogram for each NUMERICAL column (See page 348)
#-> Enable Matplotlib
# %matplotlib inline

#-> Plot the histogram of specific numerical values
histogram = titanic.hist()
